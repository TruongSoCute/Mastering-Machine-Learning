# %% [markdown]
# ## Tạo 50 hình tròn ngẫu nhiên

# %% [markdown]
# ### Nội dung đề bài:

# %% [markdown]
# **Nội dung đề bài:** Tạo 50 hình tròn ngẫu nhiên
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1\right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0,1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1\right]$

# %% [markdown]
# ### Bài làm

# %% [markdown]
# #### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# #### Sinh ngẫu nhiên hình tròn

# %%
# %%time
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
color = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2
# Out:
# CPU times: total: 0 ns
# Wall time: 87.3 μs

# %% [markdown]
# #### Kiểm tra dữ liệu

# %%
print(f'+ X: length={len(x):d}, [Min:{min(x):.2f}, Max:{max(x):.2f}]: 10 Samples [{x[0:10]}]')
print(f'+ Y: length={len(y):d}, [Min:{min(y):2f}, Max:{max(x):.2f}]: 10 Samples [{x[0:10]}]')
print(f'+ Color: length={len(color):d}, [Min:{min(color):2f}, Max: {max(color):2f}]: 10 Sample[{color[0:10]}]')
print(f'+ Area: length={len(area):d}, [Min:{min(area):2f}, Max: {max(area):2f}]: 10 Sample[{area[0:10]}]')
# Out:
# + X: length=50, [Min:0.01, Max:0.99]: 10 Samples [[0.79465898 0.83990094 0.00864829 0.34932892 0.6945308  0.53463817
#  0.75373368 0.71687387 0.17829803 0.42624848]]
# + Y: length=50, [Min:0.006377, Max:0.99]: 10 Samples [[0.79465898 0.83990094 0.00864829 0.34932892 0.6945308  0.53463817
#  0.75373368 0.71687387 0.17829803 0.42624848]]
# + Color: length=50, [Min:0.023824, Max: 0.974636]: 10 Sample[[0.74566161 0.61398916 0.02382413 0.7841852  0.21198667 0.77494951
#  0.12702137 0.1688521  0.96442575 0.64576226]]
# + Area: length=50, [Min:0.000931, Max: 693.032685]: 10 Sample[[146.23251262  70.72578064 234.02900505 272.2533419  256.97951231
#  144.66638134 200.97593532  26.19968139 226.86597688 387.63217022]]

# %% [markdown]
# #### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x,y, s=area, c=color, alpha=0.5)
plt.show()

# %% [markdown]
# ## Kết thúc
